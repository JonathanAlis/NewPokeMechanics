# %%
import pandas as pd 
df = pd.read_csv('Pokedex.csv')
df.columns
#Subtype1
#Subtype2
#Terrains (ground, water, float)
# Out:
# Index(['National\nDex', 'Pokemon\nName', 'Type', 'Kanto Dex #\n(RBYFRLG)',
#        'Kanto Dex #\n(LGPE)', 'New Dex #\n(GSC)', 'Johto Dex #\n(HGSS)',
#        'Hoenn Dex #\n(RSE)', 'Hoenn Dex #\n(ORAS)', 'Sinnoh Dex #\n(DPBDSP)',
#        'Sinnoh Dex #\n(Pt)', 'Unova Dex #\n(BW)', 'Unova Dex #\n(B2W2)',
#        'Central Kalos Dex #\n(XY)', 'Coastal Kalos Dex #\n(XY)',
#        'Mount Kalos Dex #\n(XY)', 'Alola Dex #\n(SM)', 'Melemele Dex #\n(SM)',
#        'Akala Dex #\n(SM)', 'Ula'ula Dex #\n(SM)', 'Poni Dex #\n(SM)',
#        'Alola Dex #\n(USUM)', 'Melemele Dex #\n(USUM)', 'Akala Dex #\n(USUM)',
#        'Ula'ula Dex #\n(USUM)', 'Poni Dex #\n(USUM)', 'Galar Dex #\n(SwSh)',
#        'Isle of Armor Dex #\n(SwSh)', 'Crown Tund Dex #\n(SwSh)',
#        'Hisui Dex #\n(LA)', 'Paldea Dex #\n(SV)', 'HP', 'Attack', 'Defense',
#        'Special\nAttack', 'Special\nDefense', 'Speed', 'Total', 'Type I',
#        'Type II', 'Ability I', 'Ability II', 'Hidden Ability', 'Height (ft)',
# ...

# %%
df = df[['National\nDex','Pokemon\nName','Type', 'HP', 'Attack', 'Defense',
       'Special\nAttack', 'Special\nDefense', 'Speed', 'Total', 'Type I',
       'Type II', 'Ability I', 'Ability II', 'Hidden Ability',
       'Height (m)', 'Weight (kg)', 'Pokedex Color', 'Gender Ratio', 'Egg Cycles',
       'Egg Group I', 'Egg Group II', 'Evolution\nMethod', 'Subtype 1',
       'Subtype 2']]

# %%
combined_series = pd.concat([df['Subtype 1'], df['Subtype 2']], ignore_index=True)
print(combined_series.value_counts().index)
# Out:
# Index(['Float', 'Cosmic', 'Adipose', 'Hard', 'Water Float', 'Multiple',
#        'Cruncher', 'Slasher', 'Blobby', 'Fairy', 'Water', 'Shell', 'Spiker',
#        'Horned', 'Sound', 'Serpentine', 'Kicker', 'Incisor', 'Fire', 'Flying',
#        'Light', 'Puncher', 'Fluffy', 'Grass', 'Dark', 'Dragon', 'Shooter',
#        'Pincerer', 'Wind', 'Electric', 'Exploder', 'Poison', 'Psychic', 'Ice',
#        'Ghost', 'Bug', 'Ground', 'Cocoon', 'Fighting', 'Steel', 'Rock',
#        'Normal'],
#       dtype='object')

# %%
effect={'Float': '20% resistance to Ground moves',
        'Cosmic': '20% damage increase to Cosmic moves',
        'Adipose': '20% resistance to Fire and Ice damage',
        'Hard': '20% resistance to contact moves',
        'Multiple': '20% damage increase to multi-target moves',
        'Water Float': '20% resistance to Water moves',
        'Cruncher': '20% damage increase to bite moves',
        'Slasher': '20% damage increase to slicing moves',
        'Multiple': '20% damage increase to multi-target moves',
        'Shell': '20% resistance to non-contact physical moves',
        'Blobby': '20% damage resitance to special moves',
        'Spiker': '20% damage increase to pointy moves',
        'Shell': '20% resistance to priority moves',
        'Serpentine': '20% resistance to priority moves',
        'Horned': '20% damage increase to horned moves',
        'Sound': '20% damage increase to sound moves',
        'Kicker': '20% damage increase to kicking moves',
        'Incisor': '20% damage increase to super fang (it causes 60% of remaining HP)',
        'Puncher': '20% damage increase to punch moves',
        'Light': '20% damage increase to light moves',
        'Fluffy': '20% resistance to ????? moves',
        'Shooter': '20% damage increase to shooting moves',
        'Exploder': '20% damage increase to exploding moves',
        'Wind': '20% damage increase to wind moves',
        'Cocoon': '20% resistance to ??? moves',
        
        'Grass': '20% damage increase to Grass moves',
        'Poison': '20% damage increase to Poison moves',
        'Fire': '20% damage increase to Fire moves',
        'Water': '20% damage increase to Water moves',
        'Bug': '20% damage increase to Bug moves',
        'Normal': '20% damage increase to Normal moves',
        'Electric': '20% damage increase to Electric moves',
        'Ground': '20% damage increase to Ground moves',
        'Rock': '20% damage increase to Rock moves',
        'Psychic': '20% damage increase to Psychic moves',
        'Fighting': '20% damage increase to Fighting moves',
        'Flying': '20% damage increase to Flying moves',
        'Ghost': '20% damage increase to Ghost moves',
        'Ice': '20% damage increase to Ice moves',
        'Dragon': '20% damage increase to Dragon moves',
        'Dark': '20% damage increase to Dark moves',
        'Steel': '20% damage increase to Steel moves',
        'Fairy': '20% damage increase to Fairy moves',
        }
combined_series.value_counts()
# Out:
# Float          78
# Cosmic         64
# Adipose        55
# Hard           53
# Water Float    42
# Multiple       42
# Cruncher       41
# Slasher        39
# Blobby         35
# Fairy          34
# Water          34
# Shell          33
# Spiker         33
# Horned         32
# Sound          31
# Serpentine     30
# Kicker         28
# Incisor        24
# Fire           22
# Flying         22
# Light          22
# Puncher        22
# Fluffy         21
# Grass          21
# Dark           18
# Dragon         16
# Shooter        16
# Pincerer       15
# Wind           15
# Electric       15
# Exploder       15
# Poison         14
# Psychic        14
# Ice            13
# Ghost          12
# Bug            12
# Ground         12
# Cocoon         11
# Fighting       10
# Steel           8
# Rock            7
# Normal          3
# Name: count, dtype: int64

# %%
df
# Out:
#      National\nDex    Pokemon\nName                     Type    HP  Attack  \
# 0                1        Bulbasaur                  Starter  45.0    49.0
# 1                2          Ivysaur                  Starter  60.0    62.0
# 2                3         Venusaur                  Starter  80.0    82.0
# 3              3,1  Venusaur (Mega)  Starter, Mega Evolution  80.0   100.0
# 4                4       Charmander                  Starter  39.0    52.0
# ...            ...              ...                      ...   ...     ...
# 1244          1021      Raging Bolt                      NaN   NaN     NaN
# 1245          1022     Iron Boulder                      NaN   NaN     NaN
# 1246          1023       Iron Crown                      NaN   NaN     NaN
# 1247          1024        Terapagos                      NaN   NaN     NaN
# 1248          1025        Pecharunt                      NaN   NaN     NaN
#
# ...

# %%
for category in effect:
    print(df[df==''])

# %%
for subtype in combined_series.value_counts().index:
    print(subtype)
    filtered_df = df[(df['Subtype 1'] == subtype) | (df['Subtype 2'] == subtype)]
    display(filtered_df)
# Out:
# Float
#      National\nDex    Pokemon\nName             Type    HP  Attack  Defense  \
# 42            26,1  Raichu (Alolan)      Alolan Form  60.0    85.0     50.0
# 117             81        Magnemite              NaN  25.0    35.0     70.0
# 118             82         Magneton              NaN  50.0    60.0     95.0
# 153            109          Koffing              NaN  40.0    65.0     95.0
# 154            110          Weezing              NaN  65.0    90.0    120.0
# ...            ...              ...              ...   ...     ...      ...
# 1213           994        Iron Moth  Paradox Pokemon  80.0    70.0     60.0
# 1220          1000        Gholdengo              NaN  87.0    60.0     95.0
# 1232          1012      Polchageist              NaN   NaN     NaN      NaN
# 1233          1013         Sinischa              NaN   NaN     NaN      NaN
# 1248          1025        Pecharunt              NaN   NaN     NaN      NaN
#
# ...

# %%
subtype_cathegories={}
subtype_cathegories['type']=['Fairy', 'Water', 'Grass','Fire', 'Dragon',
                             'Flying', 'Dark','Ghost', 'Ground', 'Normal',
                             'Psychic', 'Poison', 'Electric', 'Bug',
                             'Steel', 'Fighting', 'Ice', 'Rock'
                             ]


subtype_cathegories['not type']=['Cosmic', 'Sound', 'Light', 'Wind', 'Healer'] 

subtype_cathegories['composition']=['Adipose', 'Hard', 'Shell', 'Multiple',
                                    'Blobby', 'Fluffy', 'Serpentine',
                                    'Cacoon']

subtype_cathegories['attacking']=['Cruncher', 'Slasher', 'Spiker', 'Kicker',
                                  'Horned', 'Puncher', 'Incisor',
                                  'Exploder', 'Shooter', 
                                  'Pincerer'] #10

# %%
subtype_df=pd.DataFrame(columns= ['Subtype', 'Category', 'Effect'])
subtypes = 
subtype_df
# Out:
#   Cell In[8], line 2
#     subtypes =
#                ^
# SyntaxError: invalid syntax

# %%
sound_moves = ['Alluring Voice',
'Boomburst',
'Bug Buzz',
'Chatter',
'Clanging Scales',
'Clangorous Soul',
'Clangorous Soulblaze',
'Confide',
'Disarming Voice',
'Echoed Voice',
'Eerie Spell',
'Grass Whistle',
'Growl',
'Heal Bell',
'Howl',
'Hyper Voice',
'Metal Sound',
'Noble Roar',
'Overdrive',
'Parting Shot',
'Perish Song',
'Psychic Noise',
'Relic Song',
'Roar',
'Round',
'Screech',
'Shadow Panic',
'Sing',
'Snarl',
'Snore',
'Sparkling Aria',
'Supersonic',
'Torch Song',
'Uproar']

# %%
punch_moves=['Bullet Punch',
'Comet Punch',
'Dizzy Punch',
'Double Iron Bash',
'Drain Punch',
'Dynamic Punch',
'Fire Punch',
'Focus Punch',
'Hammer Arm',
'Headlong Rush',
'Ice Hammer',
'Ice Punch',
'Jet Punch',
'Mach Punch',
'Mega Punch',
'Meteor Mash',
'Plasma Fists',
'Power-Up Punch',
'Rage Fist',
'Shadow Punch',
'Sky Uppercut',
'Surging Strikes',
'Thunder Punch',
'Wicked Blow',
]

# %%
cosmic_moves=['Draco Meteor', 'Meteor Mash', 'Cosmic Power', 'Cosmic Punch',
              'Moonblast','Meteor Beam', 'Gravity', 'Roar of Time', 'Spacial Rend', 
              'Meteor Assault', 'Meteor Beam', 'Dark Void', 'Blood Moon', 
              'Moonlight', 'Moongeist Beam', 'Morning Sun', 'Sunsteel Strike'
              'Swift', 'Prismatic Laser', 'Photon Geyser', 'Lunar Blessing', 
              'Lunar Dance', 'Hyperspace Hole', 'Hyperspace Fury', 'Eternabeam']

light_moves=['Aurora Beam', 'Aurora Veil', 'Dazzling Gleam', 'Flash', 'Diamond Storm', 
             'Lumina Crash', 'Flash Cannon', 'Glitzy Glow', 'Judgement', 'Light of Ruin',
             'Light Screen', 'Light That Burns the Sky', 'Luster Purge', 'Tail Glow',
             'Mirror Coat', 'Mirror Shot', 'Mirror Move', 'Moonlight', 'Power Gem',
             'Prismatic Laser', 'Reflect', 'Signal Beam', 'Solar Beam', 'Solar Blade']

# %%
multi-target_moves = ['Boomburst', 'Brutal Swing', 'Bulldoze', 'Discharge', 'Earthquake', 'Explosion', 'Lava Plume',
'Magnitude', 'Mind Blown', 'Parabolic Charge', 'Petal Blizzard', 'Searing Shot', 'Self-Destruct', 'Sludge Wave',
'Sparkling Aria', 'Surf', 'Synchronoise', 'Teeter Dance', 'Acid', 'Air Cutter', 'Astral Barrage', 'Bleakwind Storm',
'Blizzard', 'Breaking Swipe', 'Bubble', 'Burning Jealousy', 'Captivate', 'Clanging Scales', 'Clangorous Soulblaze',
'Core Enforcer', 'Cotton Spore', 'Dark Void', 'Dazzling Gleam', 'Diamond Storm', 'Disarming Voice', 'Dragon Energy',
'Electroweb', 'Eruption', 'Expanding Force', 'Fiery Wrath', 'Glacial Lance', 'Glaciate', 'Growl', 'Heal Block',
'Heat Wave', 'Hyper Voice', 'Icy Wind', 'Lands Wrath', 'Leer', 'Make It Rain', 'Muddy Water', 'Origin Pulse',
'Overdrive', 'Poison Gas', 'Powder Snow', 'Precipice Blades', 'Razor Leaf', 'Razor Wind', 'Relic Song',
'Rock Slide', 'Sandsear Storm', 'Shell Trap', 'Snarl', 'Splishy Splash', 'Springtide Storm', 'String Shot',
'Struggle Bug', 'Sweet Scent', 'Swift', 'Tail Whip', 'Thousand Arrows', 'Thousand Waves', 'Twister',
'Venom Drench', 'Water Spout', 'Wildbolt Storm']
# Out:
#   Cell In[1], line 1
#     multi-target_moves = ['Boomburst', 'Brutal Swing', 'Bulldoze', 'Discharge', 'Earthquake', 'Explosion', 'Lava Plume',
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
biting_moves = ['Bite', 'Crunch', '', 'Fire Fang', 'Fishious Rend', 'Hyper Fang', 
                'Ice Fang', 'Jaw Lock', 'Poison Fang', 'Psychic Fangs', 'Thunder Fang']

# %%
slicing_moves = ['Aerial Ace', 'Air Cutter', 'Air Slash', 'Aqua Cutter', 'Behemoth Blade', 'Bitter Blade', 
                 'Ceaseless Edge', 'Cross Poison', 'Cut', 'Fury Cutter', 'Kowtow Cleave', 'Leaf Blade', 
                 'Mighty Cleave', 'Night Slash', 'Population Bomb', 'Psyblade', 'Psycho Cut', 'Razor Leaf', 
                 'Razor Shell', 'Sacred Sword', 'Secret Sword', 'Slash', 'Solar Blade', 'Stone Axe', 
                 'Tachyon Cutter', 'X-Scissor']

# %%
stinging_moves = piercing_moves = ['Fell Stinger', 'Drill Run', 'Drill Peck', 'Poison Sting',
                                   'Barb Barrage', 'Pin Missile', 'Spiky Shield', 'Glacial Lance',
                                   'Horn Attack', 'Horn Drill', 'Horn Leach', 'Hyper Drill', 'Icicle Spear',
                                   'Mega Horn', 'Needle Arm', 'Peck', 'Pluck', 'Pounce', 'Spike Cannon', 'Spikes', 
                                   'Bolt Beak', 'Branch Poke']

# %%
kicking_moves = ['Axe Kick', 'Blaze Kick', 'Double Kick', 'High Jump Kick', 
                 'Jump Kick', 'Low Kick', 'Mega Kick', 'Rolling Kick', 
                 'Stomp', 'Thunderous Kick', 'Triple Arrows', 'Triple Axel', 
                 'Triple Kick', 'Pyro Ball', 'Aqua Step', 'Trop Kick', 'Triple Arrows']
kicking_moves
# Out:
# ['Axe Kick',
#  'Blaze Kick',
#  'Double Kick',
#  'High Jump Kick',
#  'Jump Kick',
#  'Low Kick',
#  'Mega Kick',
#  'Rolling Kick',
#  'Stomp',
#  'Thunderous Kick',
#  'Triple Arrows',
#  'Triple Axel',
#  'Triple Kick',
#  'Pyro Ball',
#  'Aqua Step',
#  'Trop Kick',
#  'Triple Arrows']

# %%
insicor_moves=['Super Fang']

# %%
shooting_moves['Armor Cannon', 'Aura Sphere', 'Bone Rush', 'Bonemerang', 'Dragon Darts', 'Dragon Pulse', 
               'Fleur Cannon', ]
beams = ['Aurora Beam']

# %%
combined_series
# Out:
# 0           NaN
# 1           NaN
# 2       Adipose
# 3       Adipose
# 4           NaN
#          ...
# 2493        NaN
# 2494        NaN
# 2495        NaN
# 2496        NaN
# 2497        NaN
# Length: 2498, dtype: object
